# %%
import pandas
import os
import math
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pandas as pd
from pyAgrum.lib.bn2roc import showROC

# %%
# version = '9'
# dir = r"C:\Users\Rutger Mauritz\Google Drive\Studie Toegepaste Wiskunde\Module 12\Bachelor Assignment\Datasets" + '\Model' + version
# bn = gum.loadBN(os.path.join(dir, 'BayesNetwork' + version + '.bif'))
# ie = gum.LazyPropagation(bn)
# ie.jointMutualInformation({'C', 'F'})
#bn = gum.loadBN(os.path.join(dir, 'BayesNetwork' + version + '.bif'))
# ie = gum.LazyPropagation(bn)
# ie.setEvidence({'A':0, 'B':0, 'C':[0.5, 0.5]})
# ie.makeInference()
#gnb.showInference(bn,evs={'A':[1,0], 'B':[0.2,0.8]})

version = '2'
dir = r"C:\Users\Rutger Mauritz\Google Drive\Studie Toegepaste Wiskunde\Module 12\Bachelor Assignment\Datasets" + '\Model' + version
bn = gum.loadBN(os.path.join(dir, 'BayesNetwork' + version + '.bif'))
gnb.showInformation(bn, size='20')
# Out:
# <div align='center'><svg height="332pt" viewBox="0.00 0.00 134.00 332.00" width="134pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 328)">
# <title>G</title>
# <!-- A -->
# <g class="node" id="node1"><title>A</title>
# <g id="a_node1"><a xlink:title="(0) A : 1.58496">
# <ellipse cx="58" cy="-306" fill="#9898fd" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times New Roman,serif" font-size="14.00" text-anchor="middle" x="58" y="-302.3">A</text>
# </a>
# </g>
# </g>
# <!-- B -->
# <g class="node" id="node2"><title>B</title>
# <g id="a_node2"><a xlink:title="(1) B : 1.48548">
# <ellipse cx="86" cy="-234" fill="#9087e1" rx="27" ry="18" stroke="black"/>
# <text fill="#000000" font-family="Times New Roman,serif" font-size="14.00" text-anchor="middle" x="86" y="-230.3">B</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;B -->
# <g class="edge" id="edge1"><title>A-&gt;B</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : 0.9958100963244649">
# <path d="M64.6356,-288.411C67.9134,-280.216 71.9442,-270.14 75.6181,-260.955" fill="none" stroke="#4a4a4a" stroke-width="3.78965"/>
# <polygon fill="#4a4a4a" points="78.9477,-262.055 79.412,-251.47 72.4484,-259.455 78.9477,-262.055" stroke="#4a4a4a" stroke-width="3.78965"/>
# </a>
# </g>
# </g>
# <!-- C -->
# <g class="node" id="node3"><title>C</title>
# <g id="a_node3"><a xlink:title="(2) C : 1.33631">
# <ellipse cx="31" cy="-162" fill="#836eb7" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times New Roman,serif" font-size="14.00" text-anchor="middle" x="31" y="-158.3">C</text>
# </a>
# </g>
# </g>
# <!-- A&#45;&gt;C -->
# <g class="edge" id="edge6"><title>A-&gt;C</title>
# <g id="a_edge6"><a xlink:title="(0, 2) : 0.9095486854577897">
# <path d="M54.7432,-287.871C50.1415,-263.67 41.688,-219.211 36.2086,-190.393" fill="none" stroke="#4a4a4a" stroke-width="3.45768"/>
# <polygon fill="#4a4a4a" points="39.5748,-189.359 34.2684,-180.189 32.698,-190.667 39.5748,-189.359" stroke="#4a4a4a" stroke-width="3.45768"/>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;C -->
# <g class="edge" id="edge2"><title>B-&gt;C</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : 1.1403328415667597">
# <path d="M74.0658,-217.811C66.7864,-208.546 57.3374,-196.52 49.1456,-186.094" fill="none" stroke="#4a4a4a" stroke-width="4.34582"/>
# <polygon fill="#4a4a4a" points="52.0792,-183.673 42.9109,-178.159 46.0991,-188.372 52.0792,-183.673" stroke="#4a4a4a" stroke-width="4.34582"/>
# </a>
# </g>
# </g>
# <!-- E -->
# <g class="node" id="node5"><title>E</title>
# <g id="a_node5"><a xlink:title="(4) E : 0.99277">
# <ellipse cx="99" cy="-90" fill="#673457" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times New Roman,serif" font-size="14.00" text-anchor="middle" x="99" y="-86.3">E</text>
# </a>
# </g>
# </g>
# <!-- B&#45;&gt;E -->
# <g class="edge" id="edge4"><title>B-&gt;E</title>
# <g id="a_edge4"><a xlink:title="(1, 4) : 0.49277445302975026">
# <path d="M87.5681,-215.871C89.7837,-191.67 93.8539,-147.211 96.4922,-118.393" fill="none" stroke="#4a4a4a" stroke-width="1.85379"/>
# <polygon fill="#4a4a4a" points="100,-118.467 97.4263,-108.189 93.0291,-117.829 100,-118.467" stroke="#4a4a4a" stroke-width="1.85379"/>
# </a>
# </g>
# </g>
# <!-- D -->
# <g class="node" id="node4"><title>D</title>
# <g id="a_node4"><a xlink:title="(3) D : 1.33631">
# <ellipse cx="27" cy="-90" fill="#836eb7" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times New Roman,serif" font-size="14.00" text-anchor="middle" x="27" y="-86.3">D</text>
# </a>
# </g>
# </g>
# <!-- C&#45;&gt;D -->
# <g class="edge" id="edge5"><title>C-&gt;D</title>
# <g id="a_edge5"><a xlink:title="(2, 3) : 1.3363065938672796">
# <path d="M30.0112,-143.697C29.5704,-135.983 29.0407,-126.712 28.5493,-118.112" fill="none" stroke="#4a4a4a" stroke-width="5.1"/>
# <polygon fill="#4a4a4a" points="33.0032,-117.833 27.9774,-108.104 24.0928,-118.343 33.0032,-117.833" stroke="#4a4a4a" stroke-width="5.1"/>
# </a>
# </g>
# </g>
# <!-- F -->
# <g class="node" id="node6"><title>F</title>
# <g id="a_node6"><a xlink:title="(5) F : 0.69089">
# <ellipse cx="63" cy="-18" fill="#4d0102" rx="27" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times New Roman,serif" font-size="14.00" text-anchor="middle" x="63" y="-14.3">F</text>
# </a>
# </g>
# </g>
# <!-- D&#45;&gt;F -->
# <g class="edge" id="edge7"><title>D-&gt;F</title>
# <g id="a_edge7"><a xlink:title="(3, 5) : 0.0370515431541483">
# <path d="M35.3496,-72.7646C39.7115,-64.2831 45.1469,-53.7144 50.0413,-44.1974" fill="none" stroke="#4a4a4a" stroke-width="0.1"/>
# <polygon fill="#4a4a4a" points="53.2346,-45.6409 54.6957,-35.1473 47.0096,-42.4395 53.2346,-45.6409" stroke="#4a4a4a" stroke-width="0.1"/>
# </a>
# </g>
# </g>
# <!-- E&#45;&gt;F -->
# <g class="edge" id="edge3"><title>E-&gt;F</title>
# <g id="a_edge3"><a xlink:title="(4, 5) : 0.18418086654923535">
# <path d="M90.6504,-72.7646C86.2885,-64.2831 80.8531,-53.7144 75.9587,-44.1974" fill="none" stroke="#4a4a4a" stroke-width="0.666206"/>
# <polygon fill="#4a4a4a" points="78.9904,-42.4395 71.3043,-35.1473 72.7654,-45.6409 78.9904,-42.4395" stroke="#4a4a4a" stroke-width="0.666206"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div><div align='center'><font color='#4d0102'>0.6908938711268898</font><img style='vertical-align:middle' src='...'><font color='#9898fd'>1.584962500721156</font></div>

# %%
# learner = gum.BNLearner(os.path.join(dir, 'Data' + version + '.csv'))
# learner.useScoreBDeu()
# bn = learner.learnBN()
# bn.cpt('A')

# joint = bn.cpt(list(bn.nodes())[0])
# for n in list(bn.nodes())[1:]:
#     joint=joint*bn.cpt(n)

# joint[0,0,0]
# joint
